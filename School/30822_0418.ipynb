# %% [markdown]
# ## **자습**
#
# **5주 전**
#
# 11T 전에는 dictionary, for 과 while 문의 사용법을 배웠다.
#
# 10T 전에는 Pandas의 Series, DataFrame 을 배웠다.
#
# **4주 전**
#
# 9T 전에는 Numpy와 Matplotlib.pyplot의 사용법을 배웠다.
#
# 8T 전에는 Folium Library의 사용법을 배웠다.
#
# **3주 전**
#
# 7T 전에는 대단원 평가를 진행했다.
#
# 6T 전에는 Python을 이용하여 median, average, mode를 구했다. 또 알맞은 데이터의 통계를 구했다.
#
# **2주 전**
#
# 5T 전에는 Python을 이용하여 분산과 표준편차를 구하고 그 값을 그래프의 형태로 나타냈다. sklearn
#
# 4T 전에는 산점도와 데이터셋을 이용하여 최소 제곱법을 활용한 최적의 곡선(직선)을 찾는 방법을 알아보았다.
#
# **지난 주**
#
# 3T 전에는 모델을 구하고 모델에 대한 성능 지표(평균제곱오차, 결정계수)를 구하는 방법을 알아보았다.
#
# 2T 전에는 대단원 평가를 진행했다.
#
# **이번 주**
#
# 지난 시간에는 05월 15일 수행평가 준비를 위해서 인공지능에 관하여 학습했다.
#
# 이번 시간에는 자습을 진행함. (학습 내용 없음)
