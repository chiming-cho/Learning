# %% [markdown]
# ## **대단원 평가**
#
# **지난 시간에..**
#
# 4T 전에는 List 와 Dictionary, for 과 while 문의 사용법을 배웠다.
#
# 3T 전에는 Pandas의 Series, DataFrame 을 배웠다.
#
# 2T 전에는 Numpy와 Matplotlib.pyplot의 사용법을 배웠다.
#
# 지난 시간에는 Folium Library의 사용법을 배웠다.

# %% [markdown]
# 1. 여러 형태의 데이터를 분석하여 데이터로부터 지식과 인사이트를 창출하여 올바른 의사 결정에 도움을 주는 학문이다.
# 2. 문제 정의 > 데이터 수집 > 데이터 전처리 > 데이터 분석 모델 수립 > 모델 적용 및 결과 구현
# 3. 설명 분석: 우리 학교 학생들의 평균 키 조사
#
#    진단 분석: 우리 학교 학생들은 왜 지각을 하는가
#
#    예측 분석: 나이와 심장 마비 위험 간의 관계
#
#    처방 분석: 도로 교통 프로그램, 알파고
# 4. 정형 데이터: csv
#    반정형 데이터: Log, HTML, CSS
#    비정형 데이터: 영상, 인터넷 댓글
# 5. 빅데이터 특성의 3V: Volume, Velocity, Variety

# %%
#8
import csv
file_open=open('/daegu.csv','r')
data=csv.reader(file_open, delimiter=',')
for row in data:
  print(row)
# Out:
# ['지점명', '일시', '평균기온(℃)', 'highest', '\t최고기온시각', 'lowest', '최저기온시각일교차', '']
# ['대구', '2020-01-01', '0.2', '4.6', '14:19', '-4.9', '2:10', '9.5']
# ['대구', '2020-01-02', '3.4', '7.3', '14:27', '-1.7', '3:27', '9']
# ['대구', '2020-01-03', '3.6', '8.6', '15:22', '-0.8', '7:36', '9.4']
# ['대구', '2020-01-04', '2.7', '8.6', '14:43', '-2.3', '6:47', '10.9']
# ['대구', '2020-01-05', '2.2', '10.2', '15:17', '-4.3', '7:50', '14.5']
# ['대구', '2020-01-06', '1.4', '3', '23:59', '-1.4', '1:54', '4.4']
# ['대구', '2020-01-07', '7', '15.7', '22:40', '2.9', '0:44', '12.8']
# ['대구', '2020-01-08', '7.9', '14.1', '0:02', '5.4', '22:44', '8.7']
# ['대구', '2020-01-09', '3.2', '6.5', '15:26', '1', '23:54', '5.5']
# ['대구', '2020-01-10', '2.2', '9.2', '15:30', '-3.6', '7:34', '12.8']
# ['대구', '2020-01-11', '3.3', '8', '15:43', '-0.2', '8:07', '8.2']
# ['대구', '2020-01-12', '2.7', '6.5', '14:38', '0.2', '1:17', '6.3']
# ['대구', '2020-01-13', '2.1', '5.5', '14:36', '-0.6', '23:27', '6.1']
# ...

# %%
#9
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.DataFrame({"city":["서울","부산","광주","대구"],"pop":["000","000",1000,1000],"year":[2000,2001,2002,2002]})
data
# Out:
#   city   pop  year
# 0   서울   000  2000
# 1   부산   000  2001
# 2   광주  1000  2002
# 3   대구  1000  2002
