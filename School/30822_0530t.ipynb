# %% [markdown]
# #### 1. 문제 정의
# - 교재나 오렌지 교재 또는 1학년때 하였던 활동을 심화하는 주제에서 선택하는 것을 권장.
# - 평소에 생각했던 주제로 문제 정의 가능
# - 기계학습 모델로 해결 가능한 문제를 선정해야 함
#
# #### 2. 적절한 학습 모델 선택
# - 어떤 알고리즘 선택, 어떤 모델 사용
#
# #### 3. 데이터 수집
# - 데이터가 어떻게 구성되어 있는가
#
# #### 4. 데이터 전처리
# - 데이터 시각화 작업 필요
#
# #### 5. 프로그램 코딩하기
# - 프로그램 통하여 제작, 프로그램 코드 설명
