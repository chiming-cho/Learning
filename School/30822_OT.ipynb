# %% [markdown]
# 데이터 과학 시작

# %%
print("Insung Cho")
# Out:
# Insung Cho

# %%
import io
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
uploaded = files.upload() # 파일 업로드: paju2025.csv

file_name = list(uploaded.keys())[0]  # 업로드된 파일 이름 자동으로 가져오기
df = pd.read_csv(io.StringIO(uploaded[file_name].decode('cp949')))


# # 업로드한 파일 CSV 읽어오기
# df = pd.read_csv(io.StringIO(uploaded['paju2025.csv'].decode('cp949')))

plt.plot(df['최고기온(℃)'])
plt.plot(df['최저기온(℃)'])
plt.plot(df['평균기온(℃)'])
plt.plot(df['일교차'])
# Out:
#      <input type="file" id="files-242595c0-9fcc-4d31-a68c-138634e8f593" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-242595c0-9fcc-4d31-a68c-138634e8f593">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import io
import pandas as pd
import matplotlib.pyplot as plt

# 파일 업로드
uploaded = files.upload()

# 업로드된 파일의 실제 이름 확인
print(uploaded.keys())  # 여기에 나오는 파일 이름을 확인
# Out:
#      <input type="file" id="files-1cc187ec-a31d-47b5-b935-baef042f48da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1cc187ec-a31d-47b5-b935-baef042f48da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
